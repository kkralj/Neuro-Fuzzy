# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def neuron(x, w, s):
    return 1. / (1 + abs(x - w) / abs(s))

# %%
X = np.linspace(-8, 10, 100)

for s in [0.25, 1, 4]:
    y = neuron(X, 2, s)
    plt.plot(X, y, label=str(s))

plt.legend()
plt.show()

# %%
def readPoints(path):
    X1, X2, Y = [], [], []
    with open(path, 'r') as file:
        lines = file.read().splitlines()
        for line in lines:
            x1, x2, y1, y2, y3 = line.split()
            X1.append(float(x1))
            X2.append(float(x2))
            Y.append(np.argmax([y1, y2, y3]))
    return np.array(X1), np.array(X2), np.array(Y)

# %%
X1, X2, Y = readPoints('../lab7-data/zad7-dataset.txt')
markers = ['s', 'o', '^']
colors = ['r', 'y', 'b']

for i in range(len(X1)):
    plt.scatter(X1[i], X2[i], marker=markers[Y[i]], color=colors[Y[i]])
plt.show()

# %%
def readNeuronPoints(path):
    points = []
    with open(path, 'r') as file:
        lines = file.read().splitlines()
        for line in lines:
            points.append(float(line))
    return int(points[0]), points[1:]

# %%
first_hidden, points = readNeuronPoints('../lab7-data/train-params-283.txt')
Uxi, Uyi = [], []
for i in range(0, first_hidden * 4, 4):
    Uxi.append(points[i])
    Uyi.append(points[i + 2])
    
for i in range(len(X1)):
    plt.scatter(X1[i], X2[i], marker=markers[Y[i]], color=colors[Y[i]])
plt.scatter(Uxi, Uyi, c='g')
    
plt.show()

# %%
print('U')
for i in range(len(Uxi)):
    print('%f %f' % (points[4 * i], points[4 * i + 2]))

print('S')
for i in range(len(Uxi)):
    print('%f %f' % (points[4 * i + 1], points[4 * i + 3]))
    
print('Izlazni sloj')

for i in range(first_hidden * 4, len(points)):
    if (i - first_hidden * 4) % 9 == 0:
        print()
    print(points[i])
# Out:
# U
# 0.619973 0.742226
# 0.869142 0.731683
# 0.626455 0.257441
# 0.127938 0.741718
# 0.367101 0.739431
# 0.132395 0.268049
# 0.870595 0.258720
# 0.374776 0.262722
# S
# -0.056248 -0.179939
# 0.159154 -0.323668
# -0.088950 0.186235
# 0.090791 0.166136
# -0.088249 -0.222435
# -0.163410 0.347386
# -0.132169 0.215877
# 0.137616 0.314033
# Izlazni sloj
#
# 0.4026849945417258
# 81.87106142745205
# -37.52574810921834
# -58.67982102153743
# -36.58224210706143
# -22.635419318436792
# 45.94281800180695
# 52.436337805940404
# -27.930662686740032
#
# -0.06110901289703537
# -42.51530403212951
# 43.49577548991579
# -19.14166635827046
# 55.31670352545284
# -53.59819351522416
# -43.76772274710136
# -37.40633494911651
# 65.3594363606356
#
# -2.999168985522053
# -40.08452189496864
# -20.14347470978033
# 78.35699426594525
# -15.447785372578286
# 73.80654179186186
# -31.43249324851358
# -18.059173137225088
# -33.99642875087302
